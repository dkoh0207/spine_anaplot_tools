# %%
import toml
from analysis import Analysis

import pandas as pd

import uproot

# %%
cfg = """
[[this_includes]]
file = 'configurations/common/variables_nue.toml'

[[this_includes]]
file = 'configurations/common/styles.toml'

[samples]
[samples.mc]
key = "mc"
exposure_type = "pot"
trees = ['selectedNu', 'selectedCos']

[output]
path = './'

[analysis]
ordinate_sample = 'mc'
category_branch = 'category'
category_assignment = [[0], [1], [2], [3], [4], [5]]
category_labels = ['$\\nu_e$ 1eNp', '$\\nu_e$ CC', '$\\nu_e$ NC', '$\\nu_\\mu$ CC', '$\\nu_\\mu$ NC', 'Cosmic']
category_colors = ['C0', 'C1', 'C3', 'C4', 'C5', 'black']
category_types = ['histogram', 'histogram', 'histogram', 'histogram', 'histogram', 'histogram']

[[figure]]
name = 'true_edep'
type = 'SimpleFigure' 
style = 'selected_icarus_nue'
[[figure.artists]]
type = 'SpineSpectra1D'
yrange = [0, 35]
variable = 'reco_visible_energy'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

"""
# Write the string to a file
with open('cfg.toml', 'w') as f:
    f.write(cfg)

file = './nue2025_all.root'

analysis = Analysis('cfg.toml', file)
analysis.run(close_figs=False)
# Out:
# Setting weight for mc to 1.00e+00

# %%
cfg = """
[[this_includes]]
file = 'configurations/common/variables_nue.toml'

[[this_includes]]
file = 'configurations/common/styles.toml'

[samples]
[samples.mc]
key = "mc"
exposure_type = "pot"
trees = ['selectedNu', 'selectedCos']

[output]
path = './'

[analysis]
ordinate_sample = 'mc'
category_branch = 'category'
category_assignment = [[0], [1], [2], [3], [4], [5]]
category_labels = ['$\\nu_e$ 1eNp', '$\\nu_e$ CC', '$\\nu_e$ NC', '$\\nu_\\mu$ CC', '$\\nu_\\mu$ NC', 'Cosmic']
category_colors = ['C0', 'C1', 'C3', 'C4', 'C5', 'black']
category_types = ['histogram', 'histogram', 'histogram', 'histogram', 'histogram', 'histogram']

[[figure]]
name = 'true_edep'
type = 'SimpleFigure' 
style = 'selected_icarus_nue'
[[figure.artists]]
type = 'SpineSpectra1D'
yrange = [0, 35]
variable = 'reco_visible_energy'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

"""
# Write the string to a file
with open('cfg.toml', 'w') as f:
    f.write(cfg)

file = './nue2025_sys_all.root'

analysis = Analysis('cfg.toml', file)
analysis.run(close_figs=False)
# Out:
# Setting weight for mc to 1.00e+00

# %%
cfg = """
[[this_includes]]
file = 'configurations/common/styles.toml'

[samples]
[samples.cvext]
key = "cvext"
exposure_type = "pot"
trees = ['signal',]
#presel = 'contained == 1'

[output]
path = './'

[analysis]
ordinate_sample = 'cvext'
category_branch = 'category'
category_assignment = [[0], [1], [2], [3], [4], [5]]
category_labels = ['$\\nu_e$ 1eNp', '$\\nu_e$ CC', '$\\nu_e$ NC', '$\\nu_\\mu$ CC', '$\\nu_\\mu$ NC', 'Cosmic']
category_colors = ['C0', 'C1', 'C3', 'C4', 'C5', 'black']
category_types = ['histogram', 'histogram', 'histogram', 'histogram', 'histogram', 'histogram']

[variables.true_energy]
key = "true_energy"
range = [0, 3]
nbins = 25
binning_scheme = "equal_width"
xlabel = "True Neutrino Energy [GeV]"

[[figure]]
name = 'efficiency_dev'
type = 'SimpleFigure'
style = 'selected_icarus_nue'
figsize = [12.0, 6.0]
[[figure.artists]]
type = 'SpineEfficiency'
variable = 'true_energy'
groups = ['$\\nu_e$ 1eNp',]
cuts = {'fiducial_cut' = 'Fiducial', 'containment_cut' = 'Containment', 'flash_cut' = 'Flash Match', 'topological_1eNp_cut' = '1eNp', 'dedx_cut' = 'dE/dx < 3.72 MeV/cm', 'vertex_distance_cut' = 'Conversion Distance < 3.27 cm', 'directional_spread_cut' = 'Directional Spread < 0.03', 'axial_spread_cut' = 'Axial Spread > 0.27', 'start_straightness_cut' = 'Start Straightness > 0.82'}
draw_kwargs = {'show_option' = 'table', percentage = true, 'show_seqeff' = true, 'show_unseqeff' = true, npts=1e5}
"""
# Write the string to a file
with open('cfg.toml', 'w') as f:
    f.write(cfg)

file = './nue2025_cvext.root'

analysis = Analysis('cfg.toml', file)
analysis.run(close_figs=False)
# Out:
# Setting weight for cvext to 1.00e+00
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica, Helvetica Neue, Nimbus Sans, Liberation Sans, Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica, Helvetica Neue, Nimbus Sans, Liberation Sans, Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica, Helvetica Neue, Nimbus Sans, Liberation Sans, Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica, Helvetica Neue, Nimbus Sans, Liberation Sans, Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica, Helvetica Neue, Nimbus Sans, Liberation Sans, Arial
# ...

# %%
cfg = """
[[this_includes]]
file = 'configurations/common/variables_nue.toml'

[[style]]
name = 'basic'
style_sheet = "styles/muon2024.mplstyle"
markers = ['o', '^', 's', 'P', 'D']
default_figsize = [8,6]
title = 'ICARUS BNB $1eNp$ Selection'
mark_pot = true
mark_pot_horizontal = true
mark_preliminary = '$\\bf{ICARUS}$ Work-in-Progress'
plot_kwargs = {'histtype' = 'barstacked', 'stacked' = true}

[samples]
[samples.mc]
key = "mc"
exposure_type = "pot"
trees = ['selectedNu', 'selectedCos']
systematics = ['variationTree', 'multisimTree']
print_sys = "False"

# [samples.onbeam]
# key = "onbeam"
# exposure_type = "pot"
# override_category = -100
# trees = ['selectedNu',]

[[systematic_recipe]]
name = 'detsys'
label = 'Detector Systematics'
pattern = 'var(01|02|03|04|05|06|07|08|09|10)+'

[[systematic_recipe]]
name = 'flux'
label = 'Flux Systematics'
pattern = '\\b\\w*_Flux\\b'

[[systematic_recipe]]
name = 'xsec'
label = 'Interaction Systematics'
pattern = '\\bGENIEReWeight_SBN_v1_multisim_\\w+\\b'

[[systematic_recipe]]
name = 'stats'
label = 'Statistical Uncertainty'
pattern = '(mc|offbeam)_statistical'

[[systematic_recipe]]
name = 'all'
label = 'Total MC Uncertainty'
pattern = '(flux|xsec|stats|var0+)'

[[systematic_recipe]]
name = 'var00'
label = 'Detsys Null'
pattern = 'var00'

[[systematic_recipe]]
name = 'var01'
label = 'Detsys High Lifetime'
pattern = 'var01'

[[systematic_recipe]]
name = 'var02'
label = 'Detsys Low Lifetime'
pattern = 'var02'

[[systematic_recipe]]
name = 'var03'
label = 'Detsys Inc/Dec Induction1 Gain'
pattern = 'var03+'

[[systematic_recipe]]
name = 'var04'
label = 'Detsys Induction 1 Gap'
pattern = 'var04'

[[systematic_recipe]]
name = 'var05'
label = 'Detsys Ellipsoidal Recombination'
pattern = 'var05'

[[systematic_recipe]]
name = 'var06'
label = 'Detsys PMT Decreased QE'
pattern = 'var06'

[[systematic_recipe]]
name = 'var07'
label = 'Detsys YZ Non-uniformity'
pattern = 'var07'

[[systematic_recipe]]
name = 'var08'
label = 'Detsys Cathode Bending'
pattern = 'var08'

[[systematic_recipe]]
name = 'var09'
label = 'Detsys TPC Intrinsic Noise'
pattern = 'var09+'

[[systematic_recipe]]
name = 'var10'
label = 'Detsys TPC Coherent Noise'
pattern = 'var10+'

[output]
path = './'

[analysis]
ordinate_sample = 'mc'
category_branch = 'category'
category_assignment = [[0], [1], [2], [3], [4], [5]]
category_labels = ['$\\nu_e$ 1eNp', '$\\nu_e$ CC', '$\\nu_e$ NC', '$\\nu_\\mu$ CC', '$\\nu_\\mu$ NC', 'Cosmic']
category_colors = ['C0', 'C1', 'C3', 'C4', 'C5', 'black']
category_types = ['histogram', 'histogram', 'histogram', 'histogram', 'histogram', 'histogram']

[[figure]]
name = 'reco_edep'
type = 'SimpleFigure' 
style = 'basic'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_visible_energy'
yrange = [0, 50]
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false, 'draw_error' = 'all'}
"""
# Write the string to a file
with open('cfg.toml', 'w') as f:
    f.write(cfg)

file = './nue2025_sys_all.root'

analysis = Analysis('cfg.toml', file)
analysis.run(close_figs=False)
# Out:
# --Systematic(var00, Detsys Null)--
# 	Fractional uncertainty: 7.92%
# --Systematic(var01, Detsys High Lifetime)--
# 	Fractional uncertainty: 5.23%
# --Systematic(var02, Detsys Low Lifetime)--
# 	Fractional uncertainty: 0.65%
# --Systematic(var03, Detsys Inc/Dec Induction1 Gain)--
# 	Fractional uncertainty: 8.67%
# --Systematic(var04, Detsys Induction 1 Gap)--
# 	Fractional uncertainty: 0.92%
# --Systematic(var05, Detsys Ellipsoidal Recombination)--
# 	Fractional uncertainty: 4.17%
# --Systematic(var06, Detsys PMT Decreased QE)--
# 	Fractional uncertainty: 6.18%
# --Systematic(var07, Detsys YZ Non-uniformity)--
# 	Fractional uncertainty: 2.64%
# --Systematic(var08, Detsys Cathode Bending)--
# 	Fractional uncertainty: 11.64%
# --Systematic(var09, Detsys TPC Intrinsic Noise)--
# 	Fractional uncertainty: 10.87%
# --Systematic(var10, Detsys TPC Coherent Noise)--
# 	Fractional uncertainty: 5.05%
# --Systematic(GENIEReWeight_SBN_v1_multisim_ZExpAVariationResponse, None)--
# ...

# %%
import numpy as np
